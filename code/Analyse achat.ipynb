# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Chargement du fichier CSV
df = pd.read_csv("../base/achats V2.csv", encoding="ISO-8859-1", sep=';')
df
# Out:
#      ï»¿id_achat  date_achat id_produit  quantitÃ© id_fournisseur  \
# 0       PO000001  22/03/2024     P00627        150           S029
# 1       PO000002  12/06/2024     P00469         50           S028
# 2       PO000003  19/01/2024     P00849         75           S001
# 3       PO000004  20/11/2024     P00484        500           S028
# 4       PO000005  07/06/2024     P00196         50           S025
# ...          ...         ...        ...        ...            ...
# 9995    PO009996  19/06/2024     P00836        200           S028
# 9996    PO009997  08/08/2024     P00480        300           S029
# 9997    PO009998  15/12/2024     P00294        150           S029
# 9998    PO009999  10/04/2024     P00307        100           S008
# 9999    PO010000  20/05/2024     P00792         50           S029
#
#       prix_unitaire  dÃ©lai_livraison_jours
# 0            129.62                      14
# 1            110.81                       8
# 2            140.58                       8
# 3            120.77                       9
# 4            256.05                      13
# ...             ...                     ...
# 9995          22.63                       4
# 9996         236.97                       9
# 9997          77.55                      10
# 9998         102.40                      14
# 9999         171.21                      13
#
# [10000 rows x 7 columns]

# %%
# Conversion de la colonne date
df['date_achat'] = pd.to_datetime(df['date_achat'], dayfirst=True)
df
# Out:
#      ï»¿id_achat date_achat id_produit  quantitÃ© id_fournisseur  \
# 0       PO000001 2024-03-22     P00627        150           S029
# 1       PO000002 2024-06-12     P00469         50           S028
# 2       PO000003 2024-01-19     P00849         75           S001
# 3       PO000004 2024-11-20     P00484        500           S028
# 4       PO000005 2024-06-07     P00196         50           S025
# ...          ...        ...        ...        ...            ...
# 9995    PO009996 2024-06-19     P00836        200           S028
# 9996    PO009997 2024-08-08     P00480        300           S029
# 9997    PO009998 2024-12-15     P00294        150           S029
# 9998    PO009999 2024-04-10     P00307        100           S008
# 9999    PO010000 2024-05-20     P00792         50           S029
#
#       prix_unitaire  dÃ©lai_livraison_jours
# 0            129.62                      14
# 1            110.81                       8
# 2            140.58                       8
# 3            120.77                       9
# 4            256.05                      13
# ...             ...                     ...
# 9995          22.63                       4
# 9996         236.97                       9
# 9997          77.55                      10
# 9998         102.40                      14
# 9999         171.21                      13
#
# [10000 rows x 7 columns]

# %%
# Création de nouvelles variables
df['montant_total'] = df['quantité'] * df['prix_unitaire']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'quantité'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Création de nouvelles variables
# ----> 2 df['montant_total'] = df['quantité'] * df['prix_unitaire']
#       3 df
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'quantité'

# %%
# Extraction de caractéristiques temporelles
df['mois'] = df['date_achat'].dt.month
df['année'] = df['date_achat'].dt.year
df['jour_semaine'] = df['date_achat'].dt.dayofweek  # 0=lundi
df
# Out:
#       id_achat date_achat id_produit  quantité id_fournisseur  prix_unitaire  \
# 0     PO000001 2024-03-22     P00627        22           S035         129.62
# 1     PO000002 2024-06-12     P00469        51           S018         110.81
# 2     PO000003 2024-01-19     P00849        16           S046         140.58
# 3     PO000004 2024-11-20     P00484        16           S030         120.77
# 4     PO000005 2024-06-07     P00196        22           S046         256.05
# ...        ...        ...        ...       ...            ...            ...
# 9995  PO009996 2024-06-19     P00836        72           S037          22.63
# 9996  PO009997 2024-08-08     P00480        26           S012         236.97
# 9997  PO009998 2024-12-15     P00294        50           S026          77.55
# 9998  PO009999 2024-04-10     P00307        47           S042         102.40
# 9999  PO010000 2024-05-20     P00792        49           S002         171.21
#
#       délai_livraison_jours  montant_total  mois  année  jour_semaine
# 0                        14        2851.64     3   2024             4
# 1                         8        5651.31     6   2024             2
# 2                         8        2249.28     1   2024             4
# 3                         9        1932.32    11   2024             2
# 4                        13        5633.10     6   2024             4
# ...                     ...            ...   ...    ...           ...
# 9995                      4        1629.36     6   2024             2
# 9996                      9        6161.22     8   2024             3
# 9997                     10        3877.50    12   2024             6
# 9998                     14        4812.80     4   2024             2
# 9999                     13        8389.29     5   2024             0
#
# [10000 rows x 11 columns]

# %%
# Vérification des valeurs manquantes
missing = df.isnull().sum()
df
# Out:
#       id_achat date_achat id_produit  quantité id_fournisseur  prix_unitaire  \
# 0     PO000001 2024-03-22     P00627        22           S035         129.62
# 1     PO000002 2024-06-12     P00469        51           S018         110.81
# 2     PO000003 2024-01-19     P00849        16           S046         140.58
# 3     PO000004 2024-11-20     P00484        16           S030         120.77
# 4     PO000005 2024-06-07     P00196        22           S046         256.05
# ...        ...        ...        ...       ...            ...            ...
# 9995  PO009996 2024-06-19     P00836        72           S037          22.63
# 9996  PO009997 2024-08-08     P00480        26           S012         236.97
# 9997  PO009998 2024-12-15     P00294        50           S026          77.55
# 9998  PO009999 2024-04-10     P00307        47           S042         102.40
# 9999  PO010000 2024-05-20     P00792        49           S002         171.21
#
#       délai_livraison_jours  montant_total  mois  année  jour_semaine
# 0                        14        2851.64     3   2024             4
# 1                         8        5651.31     6   2024             2
# 2                         8        2249.28     1   2024             4
# 3                         9        1932.32    11   2024             2
# 4                        13        5633.10     6   2024             4
# ...                     ...            ...   ...    ...           ...
# 9995                      4        1629.36     6   2024             2
# 9996                      9        6161.22     8   2024             3
# 9997                     10        3877.50    12   2024             6
# 9998                     14        4812.80     4   2024             2
# 9999                     13        8389.29     5   2024             0
#
# [10000 rows x 11 columns]

# %%
# Encodage des variables catégorielles (id_produit, id_fournisseur)
df_encoded = pd.get_dummies(df, columns=['id_produit', 'id_fournisseur'], drop_first=True)
df
# Out:
#       id_achat date_achat id_produit  quantité id_fournisseur  prix_unitaire  \
# 0     PO000001 2024-03-22     P00627        22           S035         129.62
# 1     PO000002 2024-06-12     P00469        51           S018         110.81
# 2     PO000003 2024-01-19     P00849        16           S046         140.58
# 3     PO000004 2024-11-20     P00484        16           S030         120.77
# 4     PO000005 2024-06-07     P00196        22           S046         256.05
# ...        ...        ...        ...       ...            ...            ...
# 9995  PO009996 2024-06-19     P00836        72           S037          22.63
# 9996  PO009997 2024-08-08     P00480        26           S012         236.97
# 9997  PO009998 2024-12-15     P00294        50           S026          77.55
# 9998  PO009999 2024-04-10     P00307        47           S042         102.40
# 9999  PO010000 2024-05-20     P00792        49           S002         171.21
#
#       délai_livraison_jours  montant_total  mois  année  jour_semaine
# 0                        14        2851.64     3   2024             4
# 1                         8        5651.31     6   2024             2
# 2                         8        2249.28     1   2024             4
# 3                         9        1932.32    11   2024             2
# 4                        13        5633.10     6   2024             4
# ...                     ...            ...   ...    ...           ...
# 9995                      4        1629.36     6   2024             2
# 9996                      9        6161.22     8   2024             3
# 9997                     10        3877.50    12   2024             6
# 9998                     14        4812.80     4   2024             2
# 9999                     13        8389.29     5   2024             0
#
# [10000 rows x 11 columns]

# %%
# Normalisation des variables numériques
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
cols_to_scale = ['quantité', 'prix_unitaire', 'délai_livraison_jours', 'montant_total']
df_encoded[cols_to_scale] = scaler.fit_transform(df_encoded[cols_to_scale])
df
# Out:
#       id_achat date_achat id_produit  quantité id_fournisseur  prix_unitaire  \
# 0     PO000001 2024-03-22     P00627        22           S035         129.62
# 1     PO000002 2024-06-12     P00469        51           S018         110.81
# 2     PO000003 2024-01-19     P00849        16           S046         140.58
# 3     PO000004 2024-11-20     P00484        16           S030         120.77
# 4     PO000005 2024-06-07     P00196        22           S046         256.05
# ...        ...        ...        ...       ...            ...            ...
# 9995  PO009996 2024-06-19     P00836        72           S037          22.63
# 9996  PO009997 2024-08-08     P00480        26           S012         236.97
# 9997  PO009998 2024-12-15     P00294        50           S026          77.55
# 9998  PO009999 2024-04-10     P00307        47           S042         102.40
# 9999  PO010000 2024-05-20     P00792        49           S002         171.21
#
#       délai_livraison_jours  montant_total  mois  année  jour_semaine
# 0                        14        2851.64     3   2024             4
# 1                         8        5651.31     6   2024             2
# 2                         8        2249.28     1   2024             4
# 3                         9        1932.32    11   2024             2
# 4                        13        5633.10     6   2024             4
# ...                     ...            ...   ...    ...           ...
# 9995                      4        1629.36     6   2024             2
# 9996                      9        6161.22     8   2024             3
# 9997                     10        3877.50    12   2024             6
# 9998                     14        4812.80     4   2024             2
# 9999                     13        8389.29     5   2024             0
#
# [10000 rows x 11 columns]

# %%
# Aperçu du résultat
print(df_encoded.head())
# Out:
#    id_achat date_achat  quantité  prix_unitaire  délai_livraison_jours  \
# 0  PO000001 2024-03-22 -1.237001      -0.305617               1.610006
# 1  PO000002 2024-06-12 -0.119583      -0.530462               0.011747
# 2  PO000003 2024-01-19 -1.468191      -0.174606               0.011747
# 3  PO000004 2024-11-20 -1.468191      -0.411405               0.278124
# 4  PO000005 2024-06-07 -1.237001       1.205666               1.343630
#
#    montant_total  mois  année  jour_semaine  id_produit_P00002  ...  \
# 0      -0.863479     3   2024             4              False  ...
# 1      -0.428193     6   2024             2              False  ...
# 2      -0.957133     1   2024             4              False  ...
# 3      -1.006413    11   2024             2              False  ...
# 4      -0.431025     6   2024             4              False  ...
#
#    id_fournisseur_S041  id_fournisseur_S042  id_fournisseur_S043  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    id_fournisseur_S044  id_fournisseur_S045  id_fournisseur_S046  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                 True
# 3                False                False                False
# 4                False                False                 True
#
#    id_fournisseur_S047  id_fournisseur_S048  id_fournisseur_S049  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    id_fournisseur_S050
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 1057 columns]
